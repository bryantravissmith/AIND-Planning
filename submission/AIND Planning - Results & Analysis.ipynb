# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Project Overview

# %% [markdown]
# # Non-Heuristic Planning

# %%
results = pd.read_csv("Search Performance on Cargo Plain Problem - Sheet1.csv")
results
# Out:
#       Problem                                 Algorithm  Expansion  Goals  \
# 0   Problem 1                      breadth_first_search         43     56
# 1   Problem 1                  depth_first_graph_search         21     22
# 2   Problem 1                       uniform_cost_search         55     57
# 3   Problem 1                     astar_search with h_1         55     57
# 4   Problem 1  astar_search with h_ignore_preconditions         41     43
# 5   Problem 1           astar_search with h_pg_levelsum         11     13
# 6   Problem 2                      breadth_first_search       3343   4609
# 7   Problem 2                  depth_first_graph_search        624    625
# 8   Problem 2                       uniform_cost_search       4840   4842
# 9   Problem 2                     astar_search with h_1       4840   4842
# 10  Problem 2  astar_search with h_ignore_preconditions       1504   1506
# 11  Problem 2           astar_search with h_pg_levelsum         85     87
# ...

# %% [markdown]
# # Heuristic Planning
